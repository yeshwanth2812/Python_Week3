# %%
import matplotlib.pyplot as plt
import pylab as pl

x1 = [10,20,30]
y1 = [30,20,10]

#plt.plot(x1, y2, label = 'line1')
# plotting the line 2 points

pl.axis([0, 100, 0, 100])
pl.plot(x1, y1,'r*')
# show the plot on the screen
pl.show()

plt.xlabel('x - axis')
plt.ylabel('y - axis')
# Out:
# Text(0, 0.5, 'y - axis')
